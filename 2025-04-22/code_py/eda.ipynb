# %%
import pandas as pd

# %%
daily_accidents = pd.read_csv('../dat/daily_accidents.csv')
daily_accidents_420 = pd.read_csv('../dat/daily_accidents_420.csv')

# %%
print(daily_accidents.head)
# Out:
# <bound method NDFrame.head of             date  fatalities_count
# 0     1992-01-01               144
# 1     1992-01-02               111
# 2     1992-01-07                85
# 3     1992-01-12               127
# 4     1992-01-03               182
# ...          ...               ...
# 9127  2016-09-28               134
# 9128  2016-11-09               131
# 9129  2016-12-19               106
# 9130  2016-12-29               135
# 9131  2016-04-15               125
#
# [9132 rows x 2 columns]>

# %%
daily_accidents['date'] = pd.to_datetime(daily_accidents['date'])
daily_accidents_420['date'] = pd.to_datetime(daily_accidents_420['date'])
daily_accidents_420['e420'] = daily_accidents_420['e420'].astype('bool')

# %%
daily_accidents.dtypes
# Out:
# date                datetime64[ns]
# fatalities_count             int64
# dtype: object

# %%
daily_accidents_420.dtypes
# Out:
# date                datetime64[ns]
# e420                          bool
# fatalities_count             int64
# dtype: object

# %%
print(daily_accidents_420.head)
# Out:
# <bound method NDFrame.head of            date   e420  fatalities_count
# 0    1992-01-01  False               144
# 1    1992-01-02  False               111
# 2    1992-01-07  False                85
# 3    1992-01-12  False               127
# 4    1992-01-03  False               182
# ...         ...    ...               ...
# 9165 2016-09-28  False               134
# 9166 2016-11-09  False               131
# 9167 2016-12-19  False               106
# 9168 2016-12-29  False               135
# 9169 2016-04-15  False               125
#
# [9170 rows x 3 columns]>

# %%
daily_accidents.plot(x='date', y='fatalities_count')
# Out:
# <Axes: xlabel='date'>

# %%
daily_accidents.plot(x='date', y='fatalities_count', kind='scatter')
# Out:
# <Axes: xlabel='date', ylabel='fatalities_count'>

# %%
import seaborn as sns

# %%
sns.relplot(data=daily_accidents_420, x='date', y='fatalities_count', hue='e420')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 sns.relplot(data=daily_accidents_420, x='date', y='fatalities_count', hue='e420')
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
pip freeze
# Out:
# anyio==4.9.0
# appnope==0.1.4
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# arrow==1.3.0
# asttokens==3.0.0
# async-lru==2.0.5
# attrs==25.3.0
# babel==2.17.0
# beautifulsoup4==4.13.4
# bleach==6.2.0
# certifi==2025.1.31
# cffi==1.17.1
# charset-normalizer==3.4.1
# comm==0.2.2
# contourpy==1.3.0
# cycler==0.12.1
# debugpy==1.8.14
# decorator==5.2.1
# defusedxml==0.7.1
# exceptiongroup==1.2.2
# executing==2.2.0
# fastjsonschema==2.21.1
# fonttools==4.57.0
# fqdn==1.5.1
# h11==0.16.0
# httpcore==1.0.9
# httpx==0.28.1
# idna==3.10
# importlib_metadata==8.6.1
# importlib_resources==6.5.2
# ipykernel==6.29.5
# ipython==8.18.1
# isoduration==20.11.0
# jedi==0.19.2
# Jinja2==3.1.6
# json5==0.12.0
# jsonpointer==3.0.0
# jsonschema==4.23.0
# jsonschema-specifications==2025.4.1
# jupyter-events==0.12.0
# jupyter-lsp==2.2.5
# jupyter_client==8.6.3
# jupyter_core==5.7.2
# jupyter_server==2.15.0
# jupyter_server_terminals==0.5.3
# jupyterlab==4.4.1
# jupyterlab_pygments==0.3.0
# ...

# %%
pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
